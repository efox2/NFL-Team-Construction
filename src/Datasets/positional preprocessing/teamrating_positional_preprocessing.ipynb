# %% [markdown]
# new

# %%
import os
import pandas as pd
df = pd.read_csv('nfl22_team.csv')
df1 = pd.read_csv('nfl22_players.csv')

# %%
df1.columns
# Out:
# Index(['Team', 'FirstName', 'LastName', 'Position', 'JerseyNum',
#        'OverallRating', 'Archetype', 'SpeedRating', 'AccelerationRating',
#        'StrengthRating', 'AgilityRating', 'AwarenessRating', 'CatchingRating',
#        'CarryingRating', 'ThrowPowerRating', 'KickPowerRating',
#        'KickAccuracyRating', 'RunBlockRating', 'PassBlockRating',
#        'TackleRating', 'BreakTackleRating', 'JumpingRating',
#        'KickReturnRating', 'InjuryRating', 'StaminaRating', 'ToughnessRating',
#        'TruckingRating', 'ChangeOfDirectionRating', 'BCVisionRating',
#        'StiffArmRating', 'SpinMoveRating', 'JukeMoveRating',
#        'ImpactBlockingRating', 'RunBlockPowerRating', 'RunBlockFinesseRating',
#        'PassBlockPowerRating', 'PassBlockFinesseRating', 'LeadBlockRating',
#        'BreakSackRating', 'ThrowUnderPressureRating', 'PowerMovesRating',
#        'FinesseMovesRating', 'BlockSheddingRating', 'PursuitRating',
# ...

# %%
ideal_team = {
    'Quarter Back':3,
    'Running Back':4,
    'Offensive Lineman':9,
    'Tight End':3,
    'Wide Receiver':6,
    'Defensive Lineman':9,
    'Line Backer':7,
    'Defensive Back':10,
    'Kicker':1,
    'Punter':1,
    }
print(sum(ideal_team.values()))
df1['Position']=df1['Position'].replace({'WR':'Wide Receiver','CB':'Corner Back','TE':'Tight End','LB':'Line Backer','DE':'Defensive Lineman','DT':'Defensive Linemen','OL':'Offensive Linemen','QB':'Quarter Back','RB':'Running Back','K':'Kicker','P':'Punter','LS':'Long Snapper','S':'Safety',
'HB':'Half Back','MLB':'Line Backer','FS':'Safety','LE':'Left End','RE':'Right End','ROLB':'Line Backer','SS':'Safety','LOLB':'Line Backer',
'LT':'Left Tackle','RT':'Right Tackle','LG':'Left Guard','C':'Center','RG':'Right Guard','FB':'Full Back'})
df1['Position']=df1['Position'].replace({
 'Safety':'Defensive Back',
 'Half Back':'Running Back',
 'Left End':'Defensive Lineman',
 'Right End':'Defensive Lineman',
 'Left Tackle':'Offensive Lineman',
 'Right Tackle':'Offensive Lineman',
 'Left Guard':'Offensive Lineman',
 'Center':'Offensive Lineman',
 'Right Guard':'Offensive Lineman',
 'Full Back': 'Running Back',
 'Corner Back':'Defensive Back'})

print(df1['Position'].value_counts())

newdict={}
teams=df1['Team'].unique()
teamList=[]
for i in teams:
    df_set = df1[df1['Team']==i]
    tempdict={}
    tempdict['Team']=i
    for j in ideal_team.keys():
        dfnew = df_set[df_set['Position']==j]
        tempList= dfnew['OverallRating'].nlargest(ideal_team[j]).tolist()
        m=1
        for i in range(ideal_team[j]):
            key=j+'_'+str(m)
            tempdict[key]=tempList[i] if i<len(tempList) else 0
            m+=1
    teamList.append(tempdict)

print(len(teamList))

finaldf=pd.DataFrame(teamList)

finaldf['Team'] = finaldf['Team'].replace({'49ers':'San Francisco 49ers',
 'Bears': 'Chicago Bears',
 'Bengals':'Cincinnati Bengals',
 'Bills':'Buffalo Bills',
 'Broncos':'Denver Broncos',
 'Browns':'Cleveland Browns',
 'Buccaneers':'Tampa Bay Buccaneers',
 'Cardinals':'Arizona Cardinals',
 'Chargers':'Los Angeles Chargers',
 'Chiefs':'Kansas City Chiefs',
 'Colts': 'Indianapolis Colts',
 'Cowboys':'Dallas Cowboys',
 'Dolphins': 'Miami Dolphins',
 'Eagles':'Philadelphia Eagles',
 'Falcons':'Atlanta Falcons',
 'Football Team': 'Washington Football Team',
 'Giants': 'New York Giants',
 'Jaguars':'Jacksonville Jaguars',
 'Jets': 'New York Jets',
 'Lions':'Detroit Lions',
 'Packers':'Green Bay Packers',
 'Panthers': 'Carolina Panthers',
 'Patriots':'New England Patriots',
 'Raiders':'Las Vegas Raiders',
 'Rams':'Los Angeles Rams',
 'Ravens':'Baltimore Ravens',
 'Saints':'New Orleans Saints',
 'Seahawks':'Seattle Seahawks',
 'Steelers': 'Pittsburgh Steelers',
 'Texans':'Houston Texans',
 'Titans':'Tennessee Titans',
 'Vikings':'Minnesota Vikings'})
# Out:
# 53
# Defensive Back       378
# Offensive Lineman    341
# Line Backer          298
# Wide Receiver        214
# Defensive Lineman    172
# Running Back         164
# Tight End            162
# Defensive Linemen    117
# Quarter Back          91
# Kicker                37
# Punter                32
# Name: Position, dtype: int64
# 32

# %%
df
# Out:
#                         TEAM  OVR  DEF  OFF
# 0       Tampa Bay Buccaneers   92   90   92
# 1         Kansas City Chiefs   90   78   96
# 2          Green Bay Packers   89   85   91
# 3           Baltimore Ravens   88   85   84
# 4           Cleveland Browns   87   79   89
# 5              Buffalo Bills   86   82   86
# 6             Dallas Cowboys   86   76   88
# 7          Arizona Cardinals   85   84   83
# 8           Tennessee Titans   85   80   87
# 9       Los Angeles Chargers   84   80   82
# 10          Los Angeles Rams   84   83   81
# 11        New Orleans Saints   84   83   80
# 12      New England Patriots   83   86   78
# 13       San Francisco 49ers   83   84   80
# 14            Denver Broncos   82   86   72
# 15          Seattle Seahawks   82   77   85
# 16         Las Vegas Raiders   81   75   82
# 17  Washington Football Team   81   81   76
# 18        Indianapolis Colts   80   78   75
# 19       Pittsburgh Steelers   80   88   74
# ...

# %%
df=df[['TEAM','OVR']]
df.rename(columns = {'TEAM':'Team'}, inplace = True)
final_df = pd.merge(finaldf,df,on='Team')
final_df.rename(columns = {'OVR':'Team Rating'}, inplace = True)
# Out:
# C:\Users\Sumedh-Alienware\AppData\Local\Temp\ipykernel_29756\773058885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'TEAM':'Team'}, inplace = True)

# %%
final_df['Year']=2022

# %%
final_df
# Out:
#                         Team  Quarter Back_1  Quarter Back_2  Quarter Back_3  \
# 0        San Francisco 49ers              75              72               0
# 1              Chicago Bears              75              71              69
# 2         Cincinnati Bengals              86              54               0
# 3              Buffalo Bills              89              67               0
# 4             Denver Broncos              76              66              58
# 5           Cleveland Browns              78              66               0
# 6       Tampa Bay Buccaneers              99              63              60
# 7          Arizona Cardinals              86              62              55
# 8       Los Angeles Chargers              84              60              60
# 9         Kansas City Chiefs              97              61              52
# 10        Indianapolis Colts              73              58               0
# ...

# %%
df=pd.read_csv('nfl21_players.csv')
df['Team'].value_counts()
# Out:
# Los Angeles Rams         67
# Miami Dolphins           65
# New York Jets            65
# Cincinnati Bengals       61
# Seattle Seahawks         61
# San Francisco 49ers      60
# Washington Commanders    60
# Chicago Bears            60
# Detroit Lions            60
# Buffalo Bills            59
# Denver Broncos           59
# Philadelphia Eagles      59
# St. Louis Cardinals      59
# Atlanta Falcons          58
# Minnesota Vikings        58
# Tampa Bay Buccaneers     58
# New England Patriots     57
# Indianapolis Colts       57
# Houston Texans           57
# Cleveland Browns         56
# Dallas Cowboys           55
# Los Angeles Chargers     55
# Baltimore Ravens         55
# Kansas Chiefs            54
# Jacksonville Jaguars     54
# New York Giants          52
# Las Vegas Raiders        52
# Tennessee Titans         49
# Pittsburgh Steelers      49
# New Orleans Saints       48
# Carolina Panthers        48
# Green Bay Packers        46
# Name: Team, dtype: int64

# %%
df['Position'].value_counts()
# Out:
# WR      200
# CB      191
# TE      142
# HB      112
# DT      104
# MLB     102
# QB       94
# LE       88
# RE       85
# SS       77
# RT       72
# LOLB     71
# C        68
# LG       68
# RG       68
# FS       66
# LT       64
# ROLB     62
# P        32
# K        32
# FB       15
# Name: Position, dtype: int64

# %%
ideal_team = {
    'Quarter Back':3,
    'Running Back':4,
    'Offensive Lineman':9,
    'Tight End':3,
    'Wide Receiver':6,
    'Defensive Lineman':9,
    'Line Backer':7,
    'Defensive Back':10,
    'Kicker':1,
    'Punter':1,
    }
print(sum(ideal_team.values()))
df1['Position']=df1['Position'].replace({'WR':'Wide Receiver','CB':'Corner Back','TE':'Tight End','LB':'Line Backer','DE':'Defensive Lineman','DT':'Defensive Linemen','OL':'Offensive Linemen','QB':'Quarter Back','RB':'Running Back','K':'Kicker','P':'Punter','LS':'Long Snapper','S':'Safety',
'HB':'Half Back','MLB':'Line Backer','FS':'Safety','LE':'Left End','RE':'Right End','ROLB':'Line Backer','SS':'Safety','LOLB':'Line Backer','QB':'Quarter Back',
'LT':'Left Tackle','RT':'Right Tackle','LG':'Left Guard','C':'Center','RG':'Right Guard','FB':'Full Back'})
df1['Position']=df1['Position'].replace({
 'Safety':'Defensive Back',
 'Half Back':'Running Back',
 'Left End':'Defensive Lineman',
 'Right End':'Defensive Lineman',
 'Left Tackle':'Offensive Lineman',
 'Right Tackle':'Offensive Lineman',
 'Left Guard':'Offensive Lineman',
 'Center':'Offensive Lineman',
 'Right Guard':'Offensive Lineman',
 'Full Back': 'Running Back',
 'Corner Back':'Defensive Back'})

print(df1['Position'].value_counts())

newdict={}
teams=df1['Team'].unique()
teamList=[]
for i in teams:
    df_set = df1[df1['Team']==i]
    tempdict={}
    tempdict['Team']=i
    for j in ideal_team.keys():
        dfnew = df_set[df_set['Position']==j]
        tempList= dfnew['OverallRating'].nlargest(ideal_team[j]).tolist()
        m=1
        for i in range(ideal_team[j]):
            key=j+'_'+str(m)
            tempdict[key]=tempList[i] if i<len(tempList) else 0
            m+=1
    teamList.append(tempdict)

print(len(teamList))

finaldf=pd.DataFrame(teamList)

finaldf['Team'] = finaldf['Team'].replace({'49ers':'San Francisco 49ers',
 'Bears': 'Chicago Bears',
 'Bengals':'Cincinnati Bengals',
 'Bills':'Buffalo Bills',
 'Broncos':'Denver Broncos',
 'Browns':'Cleveland Browns',
 'Buccaneers':'Tampa Bay Buccaneers',
 'Cardinals':'Arizona Cardinals',
 'Chargers':'Los Angeles Chargers',
 'Chiefs':'Kansas City Chiefs',
 'Colts': 'Indianapolis Colts',
 'Cowboys':'Dallas Cowboys',
 'Dolphins': 'Miami Dolphins',
 'Eagles':'Philadelphia Eagles',
 'Falcons':'Atlanta Falcons',
 'Football Team': 'Washington Football Team',
 'Giants': 'New York Giants',
 'Jaguars':'Jacksonville Jaguars',
 'Jets': 'New York Jets',
 'Lions':'Detroit Lions',
 'Packers':'Green Bay Packers',
 'Panthers': 'Carolina Panthers',
 'Patriots':'New England Patriots',
 'Raiders':'Las Vegas Raiders',
 'Rams':'Los Angeles Rams',
 'Ravens':'Baltimore Ravens',
 'Saints':'New Orleans Saints',
 'Seahawks':'Seattle Seahawks',
 'Steelers': 'Pittsburgh Steelers',
 'Texans':'Houston Texans',
 'Titans':'Tennessee Titans',
 'Vikings':'Minnesota Vikings'})

df_21_team=pd.read_csv('nfl21_team.csv')
final_df_2 = pd.merge(finaldf,df_21_team,on='Team')

final_df_2['Year']=2021
# Out:
# 53
# Defensive Back       378
# Offensive Lineman    341
# Line Backer          298
# Wide Receiver        214
# Defensive Lineman    172
# Running Back         164
# Tight End            162
# Defensive Linemen    117
# Quarter Back          91
# Kicker                37
# Punter                32
# Name: Position, dtype: int64
# 32

# %%
final_df_2
# Out:
#                         Team  Quarter Back_1  Quarter Back_2  Quarter Back_3  \
# 0        San Francisco 49ers              75              72               0
# 1              Chicago Bears              75              71              69
# 2         Cincinnati Bengals              86              54               0
# 3              Buffalo Bills              89              67               0
# 4             Denver Broncos              76              66              58
# 5           Cleveland Browns              78              66               0
# 6       Tampa Bay Buccaneers              99              63              60
# 7          Arizona Cardinals              86              62              55
# 8       Los Angeles Chargers              84              60              60
# 9         Kansas City Chiefs              97              61              52
# 10        Indianapolis Colts              73              58               0
# ...

# %%
megafinal_df = pd.concat([final_df,final_df_2])

# %%
megafinal_df
# Out:
#                    Team  Quarter Back_1  Quarter Back_2  Quarter Back_3  \
# 0   San Francisco 49ers              75              72               0
# 1         Chicago Bears              75              71              69
# 2    Cincinnati Bengals              86              54               0
# 3         Buffalo Bills              89              67               0
# 4        Denver Broncos              76              66              58
# ..                  ...             ...             ...             ...
# 27     Seattle Seahawks              88              62              60
# 28  Pittsburgh Steelers              74              63              62
# 29       Houston Texans              84              70              68
# 30     Tennessee Titans              85              51               0
# 31    Minnesota Vikings              81              64              52
#
#     Running Back_1  Running Back_2  Running Back_3  Running Back_4  \
# ...

# %%
megafinal_df.to_csv('nfl_team_ratings.csv',index=False)
